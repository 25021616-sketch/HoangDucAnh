# %%
'''
W4A1
Viết chương trình Python sử dụng một trong 2 loại vòng lặp for hoặc while để
tính tống các số nguyên từ 1 đến n. (n <= 1000)
'''
n=int(input("Nhập n :"))
tong=0
for i in range(1,n+1):
  tong+=i
print(f"tổng các số từ 1 đến n : {tong}")

# %%
'''
W4A2
VIết chương trình nhập vào một số tới khi được một số nguyên dương thì thôi.
Kiểm tra số này có phải là số nguyên tố hay không?
'''
def so_nguyen_duong(n):
  if n>0:
    return True
  return False
def so_nguyen_to(n):
  if n<2:
    return False
  else:
    for i in range(2,int(n**0.5)+1):
      if n%i==0:
        return False
    return True
while True:
  n= int(input("Nhập số nguyên dương n :"))
  if n>0:
    print(f"{n} là số nguyên duong")
    break
  else:
    print(f"{n} không phải là số dương")
if so_nguyen_to(n):
  print(f"{n} là số nguyên tố")
else:
  print(f"{n} không là số nguyên tố")
# Out:
# Nhập số nguyên dương n :-9
# -9 không phải là số dương
# Nhập số nguyên dương n :9
# 9 là số nguyên duong
# 9 không là số nguyên tố

# %%
'''
W4A3
Viết chương trình tính giai thừa của một số nguyên n cho trước (n!=1×2×…×n)
với 0 < n < 100.
'''
n=int(input("Nhập n :"))
giai_thua=1
for i in range(1,n+1):
  giai_thua*=i
print(f"{giai_thua}")

# %%
'''
W4A4
Viết chương trình nhập vào một số nguyên n và in ra màn hình số chữ số (trừ dấu)
của số đó. Không dùng kiểu dữ liệu string
'''
n=int(input("Nhập số n "))
n= abs(n)
if n==0:
  so_chu_so=1
else:
  so_chu_so=0
  while n>0:
    n//=10
    so_chu_so+=1
print(f"số chữ số là {so_chu_so}")

# %%
'''
W4A5
Hãy viết một chương trình nhận vào một số nguyên dương n và một dãy gồm n số
nguyên. Nếu n số nguyên đó có số 42 thì in ra màn hình dòng chữ "I′ve found the
meaning of life!", ngược lại in ra dòng chữ "It′s a joke!".
'''
a=int(input("nhập số a"))
number=map(int,input(f"Nhập dãy số {a} nguyên: ").split())
if 42 in number:
  print("I′ve found the meaning of life")
else:
  print("It′s a joke!")
# Out:
# nhập số a3
# Nhập dãy số 3 nguyên: 32 42 43
# I′ve found the meaning of life

# %%
'''
W4A6
Nhập hai số nguyên dương a, b (a ≤ b). Hãy tính tổng các số nguyên tố trong đoạn
[a, b]. Mỗi dòng là một bộ test (a b).
'''
def so_nguyen_to(n):
  if n<2:
    return False
  else:
    for i in range(2,int(n**0.5)+1):
      if n%i==0:
        return False
    return True
a,b=map(int,input("Nhập a và b :").split())
tong=0
for i in range(a,b+1):
  if so_nguyen_to(i):
    tong+=i
print(f"tổng số nguyên tố trong(a:b) là :{tong}")

# %%
'''
W4A7
Nhập vào số nguyên dương n (n ≥ 2). Hãy in ra ước số nguyên tố lớn nhất của n
'''
def so_nguyen_to(n):
  if n<2:
    return False
  else:
    for i in range(2,int(n**0.5)+1):
      if n%i==0:
        return False
    return True
a=int(input("Nhập số nguyên duong "))
uoc_lon_nhat=1
for i in range(1,a+1):
  if a%i==0 and so_nguyen_to(i):
    uoc_lon_nhat = i
print(f"ước lớn nhất là {uoc_lon_nhat}")

# %%
'''
W4A8
Nhập số nguyên dương n. Lặp lại phép toán n = n + reverse(n) cho đến khi n là số
đối xứng (palindrome). In ra số bước và giá trị palindrome thu được.
'''

def reverse(n):
  return int(str(n)[::-1])
def palindrome(n):
  return int(str(n))==int(str(n)[::-1])
n=int(input("Nhập số nguyên dương n:"))
buoc=0
while not palindrome(n):
  n=n + reverse(n)
  buoc+=1
print(f"Số bước thực hiện: {buoc}")
print(f"Số palindrome thu được: {n}")

# %%
'''
W4A9
Nhập vào số nguyên dương n. In ra tất cả các số chính phương ≤ n có các chữ số
đôi một khác nhau (in theo thứ tự tăng dần, cùng hàng, cách nhau bởi một dấu
cách). Nếu không có, in ra (no number)
'''
def so_chinh_phuong(n):
  if int(n**0.5)**2==n:
    return True
  return False
def so_doi_mot_khach_nhau(n):
  s=str(n)
  return len(s)==len(set(s))
n=int(input("Nhập số nguyên dương n:"))
danh_sach=[]
for i in range(1,n+1):
  if so_chinh_phuong(i) and so_doi_mot_khach_nhau(i):
      danh_sach.append(i)
if len(danh_sach)==0:
     print("no number")
print(f"Danh sách sô chính phương <={n}:",*danh_sach)
# Out:
# Nhập số nguyên dương n:1000
# Danh sách sô chính phương <=1000: 1 4 9 16 25 36 49 64 81 169 196 256 289 324 361 529 576 625 729 784 841 961

# %%
'''
W4A10
Nhập vào số nguyên dương n. Tìm số x trong [1, n] có độ dài dãy Collatz lớn nhất
và in ra x cùng độ dài dãy tương ứng (x L). Nếu có nhiều số cùng độ dài, chọn số
nhỏ nhất."
'''

# %%
'''
W4A11
Viết chương trình đếm số lượng ước số chẵn của số nguyên dương n với n < 10^6.
'''
def so_chan(n):
   return n%2==0
n=int(input("nhập số nguyên dương:"))
uoc=0
for i in range(1,n+1):
  if n%i==0 and so_chan(i):
    uoc+=1
print(f"Số lượng ước số chắn của số {n} là {uoc}")

# %%
'''
W4A12
Một người có tài khoản tiết kiệm ở ngân hàng và gửi vào X đồng với lãi suất là
0.7% mỗi tháng. Viết chương trình tính số tiền sau N tháng người ấy rút được (cả
gốc và lãi, bỏ qua phần lẻ thập phân)
'''
X = int(input("Nhập số tiền gửi ban đầu (đồng): "))
N = int(input("Nhập số tháng gửi: "))
tong_tien = X * ((1 + 0.007) ** N)
tong_tien = int(tong_tien)
print(f"Sau {N} tháng, số tiền nhận được là: {tong_tien} đồng")

# %%
'''
W4A13
Hai số nguyên dương tạo thành một cặp số thân thiết khi chúng tuân theo quy luật:
Số này bằng tổng tất cả các ước của số kia (trừ chính nó) và ngược lại.
Ví dụ 220 và 284 là một cặp số thân thiết
220 ngoài chính nó ra, nó còn có 11 ước số khác là: 1, 2, 4, 5, 10, 11, 20, 44, 55,
110. Tổng của 11 ước này cho chúng ta 284
284 ngoài bản thân nó, còn có 5 ước số khác là: 1, 2, 4, 71, 142. Tổng của chúng
vừa đúng bằng 220
Nhập hai số từ bàn phím và kiểm tra xem chúng có phải là cặp số thân thiết không.
Nếu có, in ra màn hình "true", ngược lại, in ra "false
'''
def tong_uoc(n):
  tong=0
  for i in range(1,n):
    if n%i==0:
      tong += i
  return tong
a=int(input("Nhập số a:"))
b=int(input("Nhập số b:"))
if tong_uoc(a) == tong_uoc(b):
   print("True")
else:
   print("False")

# %%
'''
W4A16
In các số chẵn chia hết cho 3 bé hơn 100
'''
def so_chia_het_3(n):
  return n%3==0 and n<100
danh_sach=[]
for i in range(1,101):
  if so_chia_het_3(i):
    danh_sach.append(i)
print(f"các số chẵn chia hết cho 3 bé hơn 100 là :{danh_sach}")
# Out:
# các số chẵn chia hết cho 3 bé hơn 100 là :[3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99]

# %%
'''
W4A17
Nhập vào số nguyên dương a, in ra bảng cửu chương của a
'''
a=int(input("Nhập số nguyen dương a:"))
for i in range(1,11):
  print(f"{a} x {i} = { a*i}")
# Out:
# Nhập số nguyen dương a:5
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %%
'''
W4A18
Nhập vào số nguyên dương a và b, in toàn bộ ước chung
của a và b
'''
import math
a,b=map(int,input("nhập 2 số a và b :").split())
danh_sach=[]
for i in range(1,min(a,b)+1):
  if a%i==0 and b%i==0:
    danh_sach.append(i)

print(f"Ước chung của {a} và {b} là : ",*danh_sach)
# Out:
# nhập 2 số a và b :20 30
# Ước chung của 20 và 30 là :  1 2 5 10

# %%
'''
W4A19
Viết chương trình Python sử dụng một trong 2 loại vòng lặp
for hoặc while để in ra các số dương chẵn nhỏ hơn hoặc
bằng n (n <= 1000)
'''

n=int(input("Nhập số nguyên dương n: "))
i=2
while i<=n:
  print( i,end=" " )
  i+=2
# Out:
# Nhập số nguyên dương n: 18
# 2 4 6 8 10 12 14 16 18

# %%
'''
W4A20
Nhập vào một số nguyên dương n, kiểm tra xem n có phải là
số dạng 2^k hay không
'''
n=int(input("nhập số n: "))
la_luy_thua_2=False
for i in range(1,int(n/2)+1):
  if 2**i==n:
    la_luy_thua_2=True
    print(f"{n} có dạng 2^{i}")
    break
if not la_luy_thua_2:
   print(f"{n} không có dạng 2^k")
# Out:
# nhập số n: 10
# 10 không có dạng 2^k

# %%
'''
W4A21
Nhập vào số nguyên dương n, tính tổng các chữ số của n
'''
n=int(input("Nhập số a:"))
print(f"tổng các chữ số của {n} là :{sum(map(int,str(n)))}")
# Out:
# Nhập số a:1234567
# tổng các chữ số của 1234567 là :28

# %%
'''
W4A22
Nhập vào số nguyên dương n, đếm xem n có bao nhiêu chữ
số chẵn, bao nhiêu chữ số lẻ
'''
n=int(input('Nhập số n:'))
a=map(int,str(n))
tong_so_chan=0
tong_so_le=0
for i in a:
  if i%2==0:
    tong_so_chan +=1
  else:
    tong_so_le +=1
print("tổng các chữ số chẵn",tong_so_chan)
print('tổng các chữ số lẻ',tong_so_le)
# Out:
# Nhập số n:1234567890
# tổng các chữ số chẵn 5
# tổng các chữ số lẻ 5

# %%
'''
W4A23
Nhập n
Cho S(k) = 1 + 2 + 3 + … + k
Tìm k sao cho S(k) lớn nhất nhưng nhỏ hơn n
'''
n=int(input("nhập số n : "))
tong=0
k=0
while tong+(k+1)<n:
  k+=1
  tong+=k

print(f"với {k} thì S(k)= 1 + 2 + 3...+{k}={tong} lớn nhất nhưng nhỏ hơn {n}")
# Out:
# nhập số n : 123
# với 15 thì S(k)= 1 + 2 + 3...+15=120 lớn nhất nhưng nhỏ hơn 123

# %%
'''
W4A24
Nhập vào A, tìm n nhỏ nhất sao cho
1 + 1/2 + 1/3 + 1/4 + ... + 1/n > A
'''
a= float(input("Nhập số A: "))
tong=0
n=0
while tong <= a:
  n+=1
  tong+= 1/n

print(f"với {n} thì tổng nhỏ nhất = {tong} nhưng lớn hơn {a} ")
# Out:
# Nhập số A: 7
# với 616 thì tổng nhỏ nhất = 7.001274097134162 nhưng lớn hơn 7.0

# %%
'''
W4A25
Nhập vào một dãy số nguyên, ngưng nhập khi người dùng
nhập -1.
Sau khi nhập xong, in số lớn nhất, số nhỏ nhất trong những
số vừa nhập
'''
n=list(map(int,input("Nhập dãy số nguyên n:").split()))
tich=1
for i in n:
  tich*=i
  if tich<0:
    print("Nhập sai số")
    break
else:
    print(f"Số lớn nhất trong dãy là {max(n)}")
    print(f"Số lớn nhất trong dãy là {min(n)}")
# Out:
# Nhập dãy số nguyên n:-1 2 3 4 5
# Nhập sai số
