# %%
'''
W3A2
Hoán đổi hai số không sd biến tạm thời
Sử dụng phép toán XOR trên bit để hoán đổi giá trị của hai biến.
Đọc và tự tìm hiểu các phép toán trên bit: AND, OR, XOR
'''
a = int(input("Nhập số a: "))
b = int(input("Nhập số b: "))

print(f"Trước khi hoán đổi: a = {a}, b = {b}")

a = a ^ b
b = a ^ b
a = a ^ b

print(f"Sau khi hoán đổi: a = {a}, b = {b}")
# Out:
# Nhập số a: 5
# Nhập số b: 6
# Trước khi hoán đổi: a = 5, b = 6
# Sau khi hoán đổi: a = 6, b = 5

# %%
'''
W3A3
Kiểm tra xem một số có phải là lũy thừa của 2 hay không
Sử dụng các toán tử bitwise để xác định xem một số có phải là lũy thừa của 2
hay không.
Gợi ý: Đối với lũy thừa của 2, n & (n-1) == 0
'''
n = int(input("Nhập một số nguyên dương: "))

if n > 0 and (n & (n - 1)) == 0:
    print(f"{n} là lũy thừa của 2")
else:
    print(f"{n} không phải là lũy thừa của 2")
# Out:
# Nhập một số nguyên dương: 8
# 8 là lũy thừa của 2

# %%
'''
W3A4
Viêt chương trình chia một số m cho n, kết quả thu được làm tròn xuống
'''
import math
m = float(input("Nhập số m: "))
n = float(input("Nhập số n: "))

if n==0:
  print("Không thực hiện đươc phép tính")
else:
  ket_qua= math.floor(m/n)           # math.floor câu lệnh làm tròn xuống
  print(f"kết quả là: {ket_qua}")
# Out:
# Nhập số m: 4
# Nhập số n: 5
# kết quả là: 0

# %%
'''
W3A5
Viêt chương trình chia một số m cho n, kết quả thu được làm tròn lên
'''
import math
m = float(input("Nhập số m: "))
n = float(input("Nhập số n: "))

if n==0:
  print("Không thực hiện đươc phép tính")
else:
  ket_qua= math.ceil(m/n)      # math.ceil câu lệnh làm tròn lên
  print(f"kết quả là: {ket_qua}")
# Out:
# Nhập số m: 24
# Nhập số n: 13
# kết quả là: 2

# %%
'''
W3A6
Nhập vào một  Nếu x là số chẵn, in ra "Even". Nếu x là số lẻ, in ra "Odd"
'''
def so_chan_or_so_le(n):
  if n%2==0:
    print("Even")
  else:
    print("Odd")
a=int(input("nhập số nguyên dương n :"))
so_chan_or_so_le(a)
# Out:
# nhập số nguyên dương n :4
# Even

# %%
'''
W3A7
Nhập vào hai số nguyên a, b. Nếu cả hai số a, b đều âm thì in ra "Yes", ngược lại in ra "No"
'''
a,b=map(int,input("Nhập 2 số nguyên a và b :").split())
if a<0 and b<0 :
  print("Yes")
else:
  print("No")
# Out:
# Nhập 2 số nguyên a và b :-3 -6
# Yes

# %%
'''
W3A8
Nhập vào hai chuỗi a, b gồm các chữ cái thường. In ra "True" nếu chuỗi a dài hơn chuỗi b.
Ngược lại in ra "False"
'''
a = input()
b = input()
if len(a)>len(b):
  print("True")
else :
  print("False")
# Out:
# hgkjfdshgs
# gdhfg
# True

# %%
'''
W3A9
Nhập vào 3 số nguyên dương a, b, c. Kiểm tra xem a, b, c có cấu thành độ
dài cạnh của 1 tam giác được không. Nếu a, b, c cấu tạo thành được một tam giác,
in ra "Yes". Ngược lại in ra "No"
'''
a,b,c= map(float,input('Nhập lần lượt độ dài 3 cạnh của tam giác  :').split())

if a+b<=c or a+c<=b or b+c<=a:
    print("No")
else a+b>c and a+c>b and b+c>a:
    print("Yes")

# %%
'''
W3A10
Nhập vào 4 số nguyên. In ra màn hình số nguyên lớn nhất trong 4 số.
'''
number= map(float,input("Nhập 4 chữ số lần lượt là a,b,c,d: ").split())
print(f"số lớn nhất trong 4 chữ số là {max(number)}")

# %%
'''
W3A11 Tính tam giác: Nhâp vào ba số a,b,c bất kì. Kiểm tra xem nó có thể là
độ dài ba cạnh hay không, nếu không thì in ra màn hình 'Khong la ba canh
cua mot tam giac'. Ngược lại, kiểm tra xem nó là tam giác gì: Đều, Cân,
Vuông, hay Tam giác thường.
'''
a,b,c= map(float,input('Nhập lần lượt độ dài 3 cạnh của tam giác  :').split())

if a+b<=c or a+c<=b or b+c<=a:
    print("Đây không phải là 1 tam giác")
if a+b>c and a+c>b and b+c>a:
    if a==b==c:
      print("Đây là tâm giác đều")
    elif a==b or a==c or b==c:
      print("Đây là tam giác cân")
    elif a**2==b**2+c**2 or b**2==a**2+c**2 or c**2==b**2+a**2:
      print("Đây là tam giác vuông")
    else:
      print("Đây là tam giác thường")

# %%
'''
W3A12
Nhập vào một số nguyên dương n là số năm, kiểm tra xem năm đó có phải là
năm nhuận hay không. Năm nhuận là năm chia hết cho 4 nhưng không chia
hết cho 100, hoặc chia hết cho 400. Nếu là năm nhuận in ra "Yes", nếu không in ra "No"
'''
nam= int(input("Nhập năm"))
if nam%4==0 and nam%100!=0 or nam%400==0:
  print("Yes")
else:
  print("No")

# %%
'''
W3A14
Nhập vào hai số thực a và b của phương trình ax + b = 0. Tìm và in ra
nghiệm của phương trình, kết quả làm tròn đến số thập phân thứ 2. In ra "Vô
nghiệm" hoặc "Vô số nghiệm" trong trường hợp tương ứng
'''
a = float(input("Nhập hệ số a: "))
b = float(input("Nhập hệ số b: "))

if a == 0:
    if b == 0:
        print("Phương trình có vô số nghiệm.")
    else:
        print("Phương trình vô nghiệm.")
else:
    print(f"Nghiệm của phương trình là: x = {(-b / a):.2f}")
# Out:
# Nhập hệ số a: 4
# Nhập hệ số b: 6
# Nghiệm của phương trình là: x = -1.50

# %%
'''
W3A15
Nhập vào điểm trung bình của một học sinh và in ra học lực của học sinh đó. Xếp loại học lực theo quy tắc:
- >= 8.0: Giỏi
- >= 6.5: Khá
- >= 5.0: Trung bình
- < 5.0: Yếu
'''
diem = float(input("Nhập điểm trung bình của học sinh: "))

if diem >= 8.0:
    print("Học lực: Giỏi")
elif diem >= 6.5:
    print("Học lực: Khá")
elif diem >= 5.0:
    print("Học lực: Trung bình")
else:
    print("Học lực: Yếu")

# %%
'''
W3A16
Nhập vào một số thực: in ra kết quả làm tròn lên, tròn xuống, làm tròn tới số
nguyên gần nhất (không được sử dụng hàm sẵn có của pyton). Các kết quả
cách nhau một dấu cách
'''
x = float(input("Nhập một số thực: "))

nguyen = int(x)

#Làm tròn xuống
if x > 0 or x == nguyen :
    so_lam_tron_xuong= nguyen
else:
    so_lam_tron_xuong = nguyen-1
#Làm tròn lên
if x==nguyen or x < 0 :
    so_lam_tron_len= nguyen
else:
    so_lam_tron_len= nguyen +1
#làm tròn đến số nguyên gần nhất
if abs(x-nguyen) <0.5:
    so_lam_tron_gan_nhat=nguyen
else:
    if x>0:
        so_lam_tron_gan_nhat=nguyen+1
    else:
        so_lam_tron_gan_nhat=nguyen-1
print(so_lam_tron_xuong,so_lam_tron_len,so_lam_tron_gan_nhat)
# Out:
# Nhập một số thực: -9.4
# -10 -9 -9

# %%
'''
W3A17
Cấp số nhân
Cho 4 số a, b, c, d. Hãy kiểm tra xem 4 số này có thể theo thứ tự tạo thành 1 cấp số nhân với
công bội nguyên theo đúng thứ tự a, b, c, d hay không?
Gợi ý : Tìm công bội (b / a) nếu b chia hết cho a,
sau đó lấy b nhân công bội và so sánh vs c, c nhân công bội và so sánh vs d
'''
a,b,c,d= map(float,input("Nhập 4 số lần lượt lần là a,b,c,d ").split())
q=b/a
if b*q==c and c*q==d:
  print(f"Có thể tạo thành 1 cấp số nhân với công bội là {q}")
else:
  print("Không tạo thành cấp số nhân")
# Out:
# Nhập 4 số lần lượt lần là a,b,c,d 1 1 1 1
# Có thể tạo thành 1 cấp số nhân với công bội là 1.0
